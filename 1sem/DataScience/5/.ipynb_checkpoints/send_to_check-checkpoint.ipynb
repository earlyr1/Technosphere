# %%
import requests
import json

# %%
ip = '35.190.208.167'
user = 'radchenko'
filename = 'test.py'

with open(filename, 'rb') as f:
        resp = requests.post('http://{}:5000/{}'.format(ip, user),
                             files={'file': f})

# %%
print(json.loads(resp.text))
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.4, pytest-3.4.2, py-1.5.2, pluggy-0.6.0 -- /home/d_bolkunov/anaconda3/envs/py36raw/bin/python
# cachedir: .pytest_cache
# rootdir: /home/d_bolkunov/contents, inifile:
# collecting ... collected 24 items
#
# tests/itertools/test_groupby.py::TestGroupby::test_types xfail           [  4%]
# tests/itertools/test_groupby.py::TestGroupby::test_sizes[1-2] xfail      [  8%]
# tests/itertools/test_groupby.py::TestGroupby::test_sizes[0-2] xfail      [ 12%]
# tests/itertools/test_groupby.py::TestGroupby::test_values[1-2-sum] FAILED [ 16%]
# tests/itertools/test_groupby.py::TestGroupby::test_values[1-2-mean] FAILED [ 20%]
# tests/itertools/test_groupby.py::TestGroupby::test_values[0-2-sum] FAILED [ 25%]
# tests/itertools/test_groupby.py::TestGroupby::test_values[0-2-mean] FAILED [ 29%]
# tests/itertools/test_ngrams.py::TestNgrams::test_types XPASS             [ 33%]
# tests/itertools/test_ngrams.py::TestNgrams::test_sizes[some-correct0-2] xfail [ 37%]
# tests/itertools/test_ngrams.py::TestNgrams::test_sizes[some-correct1-3] xfail [ 41%]
# tests/itertools/test_ngrams.py::TestNgrams::test_sizes[ititititit-correct2-3] xfail [ 45%]
# tests/itertools/test_ngrams.py::TestNgrams::test_sizes[ititititit-correct3-2] xfail [ 50%]
# tests/itertools/test_ngrams.py::TestNgrams::test_sizes[ititititit-correct4-4] xfail [ 54%]
# tests/itertools/test_ngrams.py::TestNgrams::test_values[some-correct0-2] FAILED [ 58%]
# tests/itertools/test_ngrams.py::TestNgrams::test_values[some-correct1-3] FAILED [ 62%]
# tests/itertools/test_ngrams.py::TestNgrams::test_values[ititititit-correct2-3] FAILED [ 66%]
# tests/itertools/test_ngrams.py::TestNgrams::test_values[ititititit-correct3-2] FAILED [ 70%]
# tests/itertools/test_ngrams.py::TestNgrams::test_values[ititititit-correct4-4] FAILED [ 75%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[2] FAILED [ 79%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[3] FAILED [ 83%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[4] FAILED [ 87%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[5] FAILED [ 91%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[6] FAILED [ 95%]
# tests/itertools/test_permutations.py::TestPermutations::test_values[7] FAILED [100%]
#
# =================================== FAILURES ===================================
# _______________________ TestGroupby.test_values[1-2-sum] _______________________
#
# self = <tests.itertools.test_groupby.TestGroupby object at 0x7fda7e85ecf8>
# package_path = 'files/radchenko/test.py', group_col = 1, value_col = 2
# agg_function = <built-in function sum>
#
#     @pytest.mark.parametrize("agg_function", [sum, mean], ids=['sum', 'mean'])
#     @pytest.mark.parametrize("group_col,value_col", [(1, 2), (0, 2)])
#     def test_values(self, package_path, group_col, value_col, agg_function):
#         package = load_package(package_path)
#         correct = column_group_res[group_col, agg_function]
# >       out = package.group_by(DATA, group_col, value_col, agg_function)
#
# tests/itertools/test_groupby.py:71:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# data = [('Factory A', 'day 1', 100), ('Factory B', 'day 1', 200), ('Factory C', 'day 1', 100), ('Factory E', 'day 1', 300), ('Factory A', 'day 2', 200), ('Factory B', 'day 2', 200), ...]
# group_col = 1, value_col = 2, agg_function = <built-in function sum>
#
#     def group_by(data, group_col, value_col, agg_function):
#         """ Group by
#             Inputs:
#               - data: list of tuples e.g.: [('A', 2, 3), ('A', 3, 4)]
#               - group_col: int, column to group by e.g.: 0
#               - value_col: int, column to aggregate e.g: 1
#               - agg_function: agg function, so e.g. : sum
#                 it is applied to list of values in value_col
#                 for the group
#                 e.g. sum([1, 2, 3])
#             Output:
#               - out: dict group_name -> value {'A': 5}
#         """
#         out = {}
#         for curr in data:
#           i = curr[group_col]
#           j = curr[value_col]
#           if i in out:
# >           out[i] = agg_function(out[i], j)
# E           TypeError: 'int' object is not iterable
#
# files/radchenko/test.py:24: TypeError
# ______________________ TestGroupby.test_values[1-2-mean] _______________________
#
# self = <tests.itertools.test_groupby.TestGroupby object at 0x7fda7e817128>
# package_path = 'files/radchenko/test.py', group_col = 1, value_col = 2
# agg_function = <function mean at 0x7fda7ea9fb70>
#
#     @pytest.mark.parametrize("agg_function", [sum, mean], ids=['sum', 'mean'])
#     @pytest.mark.parametrize("group_col,value_col", [(1, 2), (0, 2)])
#     def test_values(self, package_path, group_col, value_col, agg_function):
#         package = load_package(package_path)
#         correct = column_group_res[group_col, agg_function]
# >       out = package.group_by(DATA, group_col, value_col, agg_function)
#
# tests/itertools/test_groupby.py:71:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# data = [('Factory A', 'day 1', 100), ('Factory B', 'day 1', 200), ('Factory C', 'day 1', 100), ('Factory E', 'day 1', 300), ('Factory A', 'day 2', 200), ('Factory B', 'day 2', 200), ...]
# group_col = 1, value_col = 2, agg_function = <function mean at 0x7fda7ea9fb70>
#
#     def group_by(data, group_col, value_col, agg_function):
#         """ Group by
#             Inputs:
#               - data: list of tuples e.g.: [('A', 2, 3), ('A', 3, 4)]
#               - group_col: int, column to group by e.g.: 0
#               - value_col: int, column to aggregate e.g: 1
#               - agg_function: agg function, so e.g. : sum
#                 it is applied to list of values in value_col
#                 for the group
#                 e.g. sum([1, 2, 3])
#             Output:
#               - out: dict group_name -> value {'A': 5}
#         """
#         out = {}
#         for curr in data:
#           i = curr[group_col]
#           j = curr[value_col]
#           if i in out:
# >           out[i] = agg_function(out[i], j)
# E           TypeError: mean() takes 1 positional argument but 2 were given
#
# files/radchenko/test.py:24: TypeError
# _______________________ TestGroupby.test_values[0-2-sum] _______________________
#
# self = <tests.itertools.test_groupby.TestGroupby object at 0x7fda7e829860>
# package_path = 'files/radchenko/test.py', group_col = 0, value_col = 2
# agg_function = <built-in function sum>
#
#     @pytest.mark.parametrize("agg_function", [sum, mean], ids=['sum', 'mean'])
#     @pytest.mark.parametrize("group_col,value_col", [(1, 2), (0, 2)])
#     def test_values(self, package_path, group_col, value_col, agg_function):
#         package = load_package(package_path)
#         correct = column_group_res[group_col, agg_function]
# >       out = package.group_by(DATA, group_col, value_col, agg_function)
#
# tests/itertools/test_groupby.py:71:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# data = [('Factory A', 'day 1', 100), ('Factory B', 'day 1', 200), ('Factory C', 'day 1', 100), ('Factory E', 'day 1', 300), ('Factory A', 'day 2', 200), ('Factory B', 'day 2', 200), ...]
# group_col = 0, value_col = 2, agg_function = <built-in function sum>
#
#     def group_by(data, group_col, value_col, agg_function):
#         """ Group by
#             Inputs:
#               - data: list of tuples e.g.: [('A', 2, 3), ('A', 3, 4)]
#               - group_col: int, column to group by e.g.: 0
#               - value_col: int, column to aggregate e.g: 1
#               - agg_function: agg function, so e.g. : sum
#                 it is applied to list of values in value_col
#                 for the group
#                 e.g. sum([1, 2, 3])
#             Output:
#               - out: dict group_name -> value {'A': 5}
#         """
#         out = {}
#         for curr in data:
#           i = curr[group_col]
#           j = curr[value_col]
#           if i in out:
# >           out[i] = agg_function(out[i], j)
# E           TypeError: 'int' object is not iterable
#
# files/radchenko/test.py:24: TypeError
# ______________________ TestGroupby.test_values[0-2-mean] _______________________
#
# self = <tests.itertools.test_groupby.TestGroupby object at 0x7fda7e817400>
# package_path = 'files/radchenko/test.py', group_col = 0, value_col = 2
# agg_function = <function mean at 0x7fda7ea9fb70>
#
#     @pytest.mark.parametrize("agg_function", [sum, mean], ids=['sum', 'mean'])
#     @pytest.mark.parametrize("group_col,value_col", [(1, 2), (0, 2)])
#     def test_values(self, package_path, group_col, value_col, agg_function):
#         package = load_package(package_path)
#         correct = column_group_res[group_col, agg_function]
# >       out = package.group_by(DATA, group_col, value_col, agg_function)
#
# tests/itertools/test_groupby.py:71:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# data = [('Factory A', 'day 1', 100), ('Factory B', 'day 1', 200), ('Factory C', 'day 1', 100), ('Factory E', 'day 1', 300), ('Factory A', 'day 2', 200), ('Factory B', 'day 2', 200), ...]
# group_col = 0, value_col = 2, agg_function = <function mean at 0x7fda7ea9fb70>
#
#     def group_by(data, group_col, value_col, agg_function):
#         """ Group by
#             Inputs:
#               - data: list of tuples e.g.: [('A', 2, 3), ('A', 3, 4)]
#               - group_col: int, column to group by e.g.: 0
#               - value_col: int, column to aggregate e.g: 1
#               - agg_function: agg function, so e.g. : sum
#                 it is applied to list of values in value_col
#                 for the group
#                 e.g. sum([1, 2, 3])
#             Output:
#               - out: dict group_name -> value {'A': 5}
#         """
#         out = {}
#         for curr in data:
#           i = curr[group_col]
#           j = curr[value_col]
#           if i in out:
# >           out[i] = agg_function(out[i], j)
# E           TypeError: mean() takes 1 positional argument but 2 were given
#
# files/radchenko/test.py:24: TypeError
# ___________________ TestNgrams.test_values[some-correct0-2] ____________________
#
# self = <tests.itertools.test_ngrams.TestNgrams object at 0x7fda7e85e438>
# package_path = 'files/radchenko/test.py', text = 'some', n = 2
# correct = Counter({'me': 1, 'om': 1, 'so': 1})
#
#     @pytest.mark.parametrize("text,correct,n", DATA)
#     def test_values(self, package_path, text, n, correct):
#         package = load_package(package_path)
#         out = package.count_ngrams(text, n)
# >       assert out == correct
# E       AssertionError: assert Counter() == Counter({'me': 1, 'om': 1, 'so': 1})
# E         Right contains more items:
# E         {'me': 1, 'om': 1, 'so': 1}
# E         Full diff:
# E         - Counter()
# E         + Counter({'me': 1, 'om': 1, 'so': 1})
#
# tests/itertools/test_ngrams.py:50: AssertionError
# ___________________ TestNgrams.test_values[some-correct1-3] ____________________
#
# self = <tests.itertools.test_ngrams.TestNgrams object at 0x7fda7e825710>
# package_path = 'files/radchenko/test.py', text = 'some', n = 3
# correct = Counter({'ome': 1, 'som': 1})
#
#     @pytest.mark.parametrize("text,correct,n", DATA)
#     def test_values(self, package_path, text, n, correct):
#         package = load_package(package_path)
#         out = package.count_ngrams(text, n)
# >       assert out == correct
# E       AssertionError: assert Counter() == Counter({'ome': 1, 'som': 1})
# E         Right contains more items:
# E         {'ome': 1, 'som': 1}
# E         Full diff:
# E         - Counter()
# E         + Counter({'ome': 1, 'som': 1})
#
# tests/itertools/test_ngrams.py:50: AssertionError
# ________________ TestNgrams.test_values[ititititit-correct2-3] _________________
#
# self = <tests.itertools.test_ngrams.TestNgrams object at 0x7fda7e7d9c50>
# package_path = 'files/radchenko/test.py', text = 'ititititit', n = 3
# correct = Counter({'iti': 4, 'tit': 4})
#
#     @pytest.mark.parametrize("text,correct,n", DATA)
#     def test_values(self, package_path, text, n, correct):
#         package = load_package(package_path)
#         out = package.count_ngrams(text, n)
# >       assert out == correct
# E       AssertionError: assert Counter() == Counter({'iti': 4, 'tit': 4})
# E         Right contains more items:
# E         {'iti': 4, 'tit': 4}
# E         Full diff:
# E         - Counter()
# E         + Counter({'iti': 4, 'tit': 4})
#
# tests/itertools/test_ngrams.py:50: AssertionError
# ________________ TestNgrams.test_values[ititititit-correct3-2] _________________
#
# self = <tests.itertools.test_ngrams.TestNgrams object at 0x7fda7e829ef0>
# package_path = 'files/radchenko/test.py', text = 'ititititit', n = 2
# correct = Counter({'it': 5, 'ti': 4})
#
#     @pytest.mark.parametrize("text,correct,n", DATA)
#     def test_values(self, package_path, text, n, correct):
#         package = load_package(package_path)
#         out = package.count_ngrams(text, n)
# >       assert out == correct
# E       AssertionError: assert Counter() == Counter({'it': 5, 'ti': 4})
# E         Right contains more items:
# E         {'it': 5, 'ti': 4}
# E         Full diff:
# E         - Counter()
# E         + Counter({'it': 5, 'ti': 4})
#
# tests/itertools/test_ngrams.py:50: AssertionError
# ________________ TestNgrams.test_values[ititititit-correct4-4] _________________
#
# self = <tests.itertools.test_ngrams.TestNgrams object at 0x7fda7e85ea58>
# package_path = 'files/radchenko/test.py', text = 'ititititit', n = 4
# correct = Counter({'itit': 4, 'titi': 3})
#
#     @pytest.mark.parametrize("text,correct,n", DATA)
#     def test_values(self, package_path, text, n, correct):
#         package = load_package(package_path)
#         out = package.count_ngrams(text, n)
# >       assert out == correct
# E       AssertionError: assert Counter() == Counter({'itit': 4, 'titi': 3})
# E         Right contains more items:
# E         {'itit': 4, 'titi': 3}
# E         Full diff:
# E         - Counter()
# E         + Counter({'itit': 4, 'titi': 3})
#
# tests/itertools/test_ngrams.py:50: AssertionError
# _______________________ TestPermutations.test_values[2] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e8250b8>
# package_path = 'files/radchenko/test.py', n = 2
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 2
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# _______________________ TestPermutations.test_values[3] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e816860>
# package_path = 'files/radchenko/test.py', n = 3
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 3
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# _______________________ TestPermutations.test_values[4] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e822710>
# package_path = 'files/radchenko/test.py', n = 4
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 4
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# _______________________ TestPermutations.test_values[5] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e806160>
# package_path = 'files/radchenko/test.py', n = 5
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 5
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# _______________________ TestPermutations.test_values[6] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e8167b8>
# package_path = 'files/radchenko/test.py', n = 6
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 6
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# _______________________ TestPermutations.test_values[7] ________________________
#
# self = <tests.itertools.test_permutations.TestPermutations object at 0x7fda7e829940>
# package_path = 'files/radchenko/test.py', n = 7
#
#     @pytest.mark.parametrize("n", range(2, 8))
#     def test_values(self, package_path, n):
#         package = load_package(package_path)
#         correct = CHECK[n]
# >       out = package.num_bad_permutations(n)
#
# tests/itertools/test_permutations.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# n = 7
#
#     def num_bad_permutations(n):
#         """
#         Number of permutations of length n
#         where each element is not on its place
#         Inputs:
#           - n: int, length of permutation
#         Output:
#           - num_perm: int, number of such permutations
#         """
#         c = 0
# >       for i in itertools.permutations(range(n)):
# E       NameError: name 'itertools' is not defined
#
# files/radchenko/test.py:40: NameError
# =============== 15 failed, 8 xfailed, 1 xpassed in 0.23 seconds ================

# %%
# echo -e $(curl -i -X POST -F "file=@./submission.py" http://35.190.208.167:5000/<surname>)

# <surname> - поменять надо
# а еще название файла можно поменять, который отправляешь
